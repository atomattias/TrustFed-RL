# %% [markdown]
# # DEPRECATED — do not use for the master D1 matrix
#
# This notebook only ran legacy **B5** (`--task agent_iomt`).
#
# **Use instead:** [`Run_TrustFed_RL_IoMT_Matrix.ipynb`](Run_TrustFed_RL_IoMT_Matrix.ipynb)
# with:
# ```bash
# !python scripts/colab_run_experiments.py --task trustfed_rl_matrix --phases B5,B5star,B4star --download
# ```
#
# See [`COLAB_INSTRUCTIONS.md`](COLAB_INSTRUCTIONS.md).
